# %% [markdown]
# ### This notebook is just a first exploratory data analysis through the dataset - mostly around class distributions

# %% [markdown]
# # import packages

# %%
# %matplotlib inline

# %%
# !pip install matplotlib
#!pip install pandoc
# !pip install nbconvert
# Out:
# Requirement already satisfied: nbconvert in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (6.0.7)
# Requirement already satisfied: jupyter-core in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbconvert) (4.7.0)
# Requirement already satisfied: defusedxml in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbconvert) (0.6.0)
# Requirement already satisfied: bleach in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbconvert) (3.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbconvert) (0.8.4)
# Requirement already satisfied: jinja2>=2.4 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbconvert) (2.11.2)
# Requirement already satisfied: nbformat>=4.4 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbconvert) (5.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbconvert) (0.5.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbconvert) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbconvert) (1.4.3)
# Requirement already satisfied: testpath in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbconvert) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbconvert) (0.1.2)
# Requirement already satisfied: pygments>=2.4.1 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbconvert) (2.7.4)
# Requirement already satisfied: traitlets>=4.2 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbconvert) (5.0.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from jinja2>=2.4->nbconvert) (1.1.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert) (6.1.11)
# Requirement already satisfied: nest-asyncio in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert) (1.4.3)
# Requirement already satisfied: async-generator in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert) (1.10)
# Requirement already satisfied: pyzmq>=13 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (21.0.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (2.8.1)
# Requirement already satisfied: tornado>=4.1 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert) (6.1)
# Requirement already satisfied: ipython-genutils in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbformat>=4.4->nbconvert) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from nbformat>=4.4->nbconvert) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (1.15.0)
# Requirement already satisfied: setuptools in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (47.1.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert) (20.3.0)
# Requirement already satisfied: packaging in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from bleach->nbconvert) (20.8)
# Requirement already satisfied: webencodings in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from bleach->nbconvert) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/dbr7755/.virtualenvs/capstone/lib/python3.8/site-packages (from packaging->bleach->nbconvert) (2.4.7)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # import the dataset

# %%
df = pd.read_csv("./data/train.csv", index_col = "observation_id")
df
# Out:
#                                                            Type  \
# observation_id
# 34d76816-cfc2-4bdd-b3a2-bf0c40b12689              Person search
# 83c87ec1-e6d4-4bbb-8e0c-159516706359              Person search
# 8c2eae4b-035a-492f-92d6-cd27e6c900a1              Person search
# e63a036a-a728-4efe-8e08-7198f56d6d0a              Person search
# 40c70aca-1f7f-4efe-8c5b-ade0f2e9937d              Person search
# ...                                                         ...
# a23dc59d-29fe-48e5-b012-81feb6acfddf              Person search
# 425fde18-f7d5-4ebe-baf4-714cadd5a445  Person and Vehicle search
# 7c249ab7-d4bf-47ef-86bd-aad51d7d2aab              Person search
# 4fa54513-20c4-4a53-a5db-8a4bb85b1e32              Person search
# 4d8604d3-9864-4fd5-a811-f8ce7bed619a              Person search
#
#                                                            Date  \
# observation_id
# 34d76816-cfc2-4bdd-b3a2-bf0c40b12689  2019-12-01T00:00:00+00:00
# 83c87ec1-e6d4-4bbb-8e0c-159516706359  2019-12-01T00:09:00+00:00
# 8c2eae4b-035a-492f-92d6-cd27e6c900a1  2019-12-01T00:10:00+00:00
# e63a036a-a728-4efe-8e08-7198f56d6d0a  2019-12-01T00:10:00+00:00
# 40c70aca-1f7f-4efe-8c5b-ade0f2e9937d  2019-12-01T00:12:00+00:00
# ...                                                         ...
# a23dc59d-29fe-48e5-b012-81feb6acfddf  2018-08-29T02:45:00+00:00
# 425fde18-f7d5-4ebe-baf4-714cadd5a445  2018-08-29T21:00:00+00:00
# 7c249ab7-d4bf-47ef-86bd-aad51d7d2aab  2018-08-29T21:10:00+00:00
# 4fa54513-20c4-4a53-a5db-8a4bb85b1e32  2018-08-29T21:15:00+00:00
# 4d8604d3-9864-4fd5-a811-f8ce7bed619a  2018-08-30T13:15:00+00:00
#
#                                      Part of a policing operation   Latitude  \
# observation_id
# 34d76816-cfc2-4bdd-b3a2-bf0c40b12689                         True        NaN
# 83c87ec1-e6d4-4bbb-8e0c-159516706359                         True        NaN
# 8c2eae4b-035a-492f-92d6-cd27e6c900a1                         True        NaN
# e63a036a-a728-4efe-8e08-7198f56d6d0a                        False        NaN
# 40c70aca-1f7f-4efe-8c5b-ade0f2e9937d                         True  50.368247
# ...                                                           ...        ...
# a23dc59d-29fe-48e5-b012-81feb6acfddf                          NaN        NaN
# 425fde18-f7d5-4ebe-baf4-714cadd5a445                        False  51.540219
# 7c249ab7-d4bf-47ef-86bd-aad51d7d2aab                        False  51.540219
# 4fa54513-20c4-4a53-a5db-8a4bb85b1e32                        False  51.540219
# 4d8604d3-9864-4fd5-a811-f8ce7bed619a                          NaN        NaN
#
#                                       Longitude  Gender Age range  \
# observation_id
# 34d76816-cfc2-4bdd-b3a2-bf0c40b12689        NaN    Male     18-24
# 83c87ec1-e6d4-4bbb-8e0c-159516706359        NaN    Male     18-24
# 8c2eae4b-035a-492f-92d6-cd27e6c900a1        NaN  Female     18-24
# e63a036a-a728-4efe-8e08-7198f56d6d0a        NaN    Male     18-24
# 40c70aca-1f7f-4efe-8c5b-ade0f2e9937d  -4.126646    Male     18-24
# ...                                         ...     ...       ...
# a23dc59d-29fe-48e5-b012-81feb6acfddf        NaN    Male     18-24
# 425fde18-f7d5-4ebe-baf4-714cadd5a445  -1.764708    Male     18-24
# 7c249ab7-d4bf-47ef-86bd-aad51d7d2aab  -1.764708    Male     18-24
# 4fa54513-20c4-4a53-a5db-8a4bb85b1e32  -1.764708    Male     18-24
# 4d8604d3-9864-4fd5-a811-f8ce7bed619a        NaN  Female   over 34
#
#                                                                  Self-defined ethnicity  \
# observation_id
# 34d76816-cfc2-4bdd-b3a2-bf0c40b12689   Asian/Asian British - Any other Asian background
# 83c87ec1-e6d4-4bbb-8e0c-159516706359                                                NaN
# 8c2eae4b-035a-492f-92d6-cd27e6c900a1  White - English/Welsh/Scottish/Northern Irish/...
# e63a036a-a728-4efe-8e08-7198f56d6d0a                                                NaN
# 40c70aca-1f7f-4efe-8c5b-ade0f2e9937d                                                NaN
# ...                                                                                 ...
# a23dc59d-29fe-48e5-b012-81feb6acfddf  White - English/Welsh/Scottish/Northern Irish/...
# 425fde18-f7d5-4ebe-baf4-714cadd5a445  White - English/Welsh/Scottish/Northern Irish/...
# 7c249ab7-d4bf-47ef-86bd-aad51d7d2aab  White - English/Welsh/Scottish/Northern Irish/...
# 4fa54513-20c4-4a53-a5db-8a4bb85b1e32  White - English/Welsh/Scottish/Northern Irish/...
# 4d8604d3-9864-4fd5-a811-f8ce7bed619a  White - English/Welsh/Scottish/Northern Irish/...
#
#                                      Officer-defined ethnicity  \
# observation_id
# 34d76816-cfc2-4bdd-b3a2-bf0c40b12689                     Asian
# 83c87ec1-e6d4-4bbb-8e0c-159516706359                     White
# 8c2eae4b-035a-492f-92d6-cd27e6c900a1                     White
# e63a036a-a728-4efe-8e08-7198f56d6d0a                     Asian
# 40c70aca-1f7f-4efe-8c5b-ade0f2e9937d                     White
# ...                                                        ...
# a23dc59d-29fe-48e5-b012-81feb6acfddf                     White
# 425fde18-f7d5-4ebe-baf4-714cadd5a445                     White
# 7c249ab7-d4bf-47ef-86bd-aad51d7d2aab                     White
# 4fa54513-20c4-4a53-a5db-8a4bb85b1e32                     White
# 4d8604d3-9864-4fd5-a811-f8ce7bed619a                     White
#
#                                                                 Legislation  \
# observation_id
# 34d76816-cfc2-4bdd-b3a2-bf0c40b12689  Misuse of Drugs Act 1971 (section 23)
# 83c87ec1-e6d4-4bbb-8e0c-159516706359  Misuse of Drugs Act 1971 (section 23)
# 8c2eae4b-035a-492f-92d6-cd27e6c900a1  Misuse of Drugs Act 1971 (section 23)
# e63a036a-a728-4efe-8e08-7198f56d6d0a  Misuse of Drugs Act 1971 (section 23)
# 40c70aca-1f7f-4efe-8c5b-ade0f2e9937d  Misuse of Drugs Act 1971 (section 23)
# ...                                                                     ...
# a23dc59d-29fe-48e5-b012-81feb6acfddf  Misuse of Drugs Act 1971 (section 23)
# 425fde18-f7d5-4ebe-baf4-714cadd5a445  Misuse of Drugs Act 1971 (section 23)
# 7c249ab7-d4bf-47ef-86bd-aad51d7d2aab  Misuse of Drugs Act 1971 (section 23)
# 4fa54513-20c4-4a53-a5db-8a4bb85b1e32  Misuse of Drugs Act 1971 (section 23)
# 4d8604d3-9864-4fd5-a811-f8ce7bed619a  Misuse of Drugs Act 1971 (section 23)
#
#                                       Object of search  \
# observation_id
# 34d76816-cfc2-4bdd-b3a2-bf0c40b12689  Controlled drugs
# 83c87ec1-e6d4-4bbb-8e0c-159516706359  Controlled drugs
# 8c2eae4b-035a-492f-92d6-cd27e6c900a1  Controlled drugs
# e63a036a-a728-4efe-8e08-7198f56d6d0a  Controlled drugs
# 40c70aca-1f7f-4efe-8c5b-ade0f2e9937d  Controlled drugs
# ...                                                ...
# a23dc59d-29fe-48e5-b012-81feb6acfddf  Controlled drugs
# 425fde18-f7d5-4ebe-baf4-714cadd5a445  Controlled drugs
# 7c249ab7-d4bf-47ef-86bd-aad51d7d2aab  Controlled drugs
# 4fa54513-20c4-4a53-a5db-8a4bb85b1e32  Controlled drugs
# 4d8604d3-9864-4fd5-a811-f8ce7bed619a  Controlled drugs
#
#                                                               Outcome  \
# observation_id
# 34d76816-cfc2-4bdd-b3a2-bf0c40b12689     A no further action disposal
# 83c87ec1-e6d4-4bbb-8e0c-159516706359     A no further action disposal
# 8c2eae4b-035a-492f-92d6-cd27e6c900a1     A no further action disposal
# e63a036a-a728-4efe-8e08-7198f56d6d0a     A no further action disposal
# 40c70aca-1f7f-4efe-8c5b-ade0f2e9937d     A no further action disposal
# ...                                                               ...
# a23dc59d-29fe-48e5-b012-81feb6acfddf     A no further action disposal
# 425fde18-f7d5-4ebe-baf4-714cadd5a445      Penalty Notice for Disorder
# 7c249ab7-d4bf-47ef-86bd-aad51d7d2aab     A no further action disposal
# 4fa54513-20c4-4a53-a5db-8a4bb85b1e32     A no further action disposal
# 4d8604d3-9864-4fd5-a811-f8ce7bed619a  Caution (simple or conditional)
#
#                                      Outcome linked to object of search  \
# observation_id
# 34d76816-cfc2-4bdd-b3a2-bf0c40b12689                                NaN
# 83c87ec1-e6d4-4bbb-8e0c-159516706359                                NaN
# 8c2eae4b-035a-492f-92d6-cd27e6c900a1                                NaN
# e63a036a-a728-4efe-8e08-7198f56d6d0a                                NaN
# 40c70aca-1f7f-4efe-8c5b-ade0f2e9937d                                NaN
# ...                                                                 ...
# a23dc59d-29fe-48e5-b012-81feb6acfddf                                NaN
# 425fde18-f7d5-4ebe-baf4-714cadd5a445                               True
# 7c249ab7-d4bf-47ef-86bd-aad51d7d2aab                                NaN
# 4fa54513-20c4-4a53-a5db-8a4bb85b1e32                                NaN
# 4d8604d3-9864-4fd5-a811-f8ce7bed619a                                NaN
#
#                                      Removal of more than just outer clothing  \
# observation_id
# 34d76816-cfc2-4bdd-b3a2-bf0c40b12689                                    False
# 83c87ec1-e6d4-4bbb-8e0c-159516706359                                    False
# 8c2eae4b-035a-492f-92d6-cd27e6c900a1                                    False
# e63a036a-a728-4efe-8e08-7198f56d6d0a                                    False
# 40c70aca-1f7f-4efe-8c5b-ade0f2e9937d                                    False
# ...                                                                       ...
# a23dc59d-29fe-48e5-b012-81feb6acfddf                                      NaN
# 425fde18-f7d5-4ebe-baf4-714cadd5a445                                    False
# 7c249ab7-d4bf-47ef-86bd-aad51d7d2aab                                    False
# 4fa54513-20c4-4a53-a5db-8a4bb85b1e32                                    False
# 4d8604d3-9864-4fd5-a811-f8ce7bed619a                                      NaN
#
#                                                  station
# observation_id
# 34d76816-cfc2-4bdd-b3a2-bf0c40b12689  devon-and-cornwall
# 83c87ec1-e6d4-4bbb-8e0c-159516706359  devon-and-cornwall
# 8c2eae4b-035a-492f-92d6-cd27e6c900a1  devon-and-cornwall
# e63a036a-a728-4efe-8e08-7198f56d6d0a  devon-and-cornwall
# 40c70aca-1f7f-4efe-8c5b-ade0f2e9937d  devon-and-cornwall
# ...                                                  ...
# a23dc59d-29fe-48e5-b012-81feb6acfddf           wiltshire
# 425fde18-f7d5-4ebe-baf4-714cadd5a445           wiltshire
# 7c249ab7-d4bf-47ef-86bd-aad51d7d2aab           wiltshire
# 4fa54513-20c4-4a53-a5db-8a4bb85b1e32           wiltshire
# 4d8604d3-9864-4fd5-a811-f8ce7bed619a           wiltshire
#
# [660611 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['Type', 'Date', 'Part of a policing operation', 'Latitude', 'Longitude',
#        'Gender', 'Age range', 'Self-defined ethnicity',
#        'Officer-defined ethnicity', 'Legislation', 'Object of search',
#        'Outcome', 'Outcome linked to object of search',
#        'Removal of more than just outer clothing', 'station'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Type                                             0
# Date                                             0
# Part of a policing operation                153564
# Latitude                                    112316
# Longitude                                   112316
# Gender                                           0
# Age range                                        0
# Self-defined ethnicity                        5574
# Officer-defined ethnicity                        0
# Legislation                                  27940
# Object of search                                 0
# Outcome                                          0
# Outcome linked to object of search          473100
# Removal of more than just outer clothing    426549
# station                                          0
# dtype: int64

# %% [markdown]
# Several columns with NaNs, most seems in unimportant columns which might not be used or can be replaced by False in case of binary

# %%
# how many stations are we working with?
df.station.nunique(), df.station.unique()
# Out:
# (42,
#  array(['devon-and-cornwall', 'dyfed-powys', 'derbyshire', 'bedfordshire',
#         'avon-and-somerset', 'cheshire', 'sussex', 'north-yorkshire',
#         'cleveland', 'merseyside', 'north-wales', 'wiltshire', 'norfolk',
#         'suffolk', 'thames-valley', 'durham', 'warwickshire',
#         'leicestershire', 'hertfordshire', 'cumbria', 'metropolitan',
#         'essex', 'south-yorkshire', 'surrey', 'staffordshire',
#         'northamptonshire', 'northumbria', 'city-of-london',
#         'nottinghamshire', 'gloucestershire', 'cambridgeshire',
#         'lincolnshire', 'btp', 'west-yorkshire', 'dorset', 'west-mercia',
#         'kent', 'hampshire', 'humberside', 'lancashire',
#         'greater-manchester', 'gwent'], dtype=object))

# %%
df["station"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# how many different outcomes we have?
df.Outcome.nunique(), df.Outcome.unique()
# Out:
# (16,
#  array(['A no further action disposal', 'Arrest', 'Community resolution',
#         'Summons / charged by post', 'Khat or Cannabis warning',
#         'Caution (simple or conditional)', 'Penalty Notice for Disorder',
#         'Nothing found - no further action',
#         'Offender given drugs possession warning', 'Local resolution',
#         'Suspect arrested', 'Article found - Detailed outcome unavailable',
#         'Offender cautioned', 'Suspect summonsed to court',
#         'Offender given penalty notice',
#         'Suspected psychoactive substances seized - No further action'],
#        dtype=object))

# %%
df.Outcome.value_counts().plot(kind='bar')
plt.xlabel("Outcome")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df.Outcome.value_counts(normalize = True)
# Out:
# A no further action disposal                                    0.689274
# Arrest                                                          0.142471
# Community resolution                                            0.062535
# Khat or Cannabis warning                                        0.025996
# Nothing found - no further action                               0.024505
# Summons / charged by post                                       0.018516
# Penalty Notice for Disorder                                     0.016975
# Suspect arrested                                                0.007037
# Caution (simple or conditional)                                 0.004812
# Offender given drugs possession warning                         0.003182
# Local resolution                                                0.002018
# Suspect summonsed to court                                      0.000963
# Article found - Detailed outcome unavailable                    0.000793
# Offender given penalty notice                                   0.000627
# Offender cautioned                                              0.000286
# Suspected psychoactive substances seized - No further action    0.000011
# Name: Outcome, dtype: float64

# %% [markdown]
# There are many different Outcomes - ask which should be considered a success search? Looking to turn this into a binary problem, search or no search

# %%
# how many age ranges we have?
df["Age range"].nunique(), df["Age range"].unique()
# Out:
# (5, array(['18-24', '25-34', 'over 34', '10-17', 'under 10'], dtype=object))

# %%
df["Age range"].value_counts().plot(kind="bar")
plt.xlabel("Age");
plt.ylabel("Count");

# %%
df["Age range"].value_counts(normalize=True)
# Out:
# 18-24       0.366184
# 25-34       0.239447
# 10-17       0.199456
# over 34     0.194332
# under 10    0.000581
# Name: Age range, dtype: float64

# %% [markdown]
# There seems to be a weird age which is under 10, most likely to be dropped

# %%
# Let's check on gender distribution
df["Gender"].value_counts().plot(kind="bar")
plt.xlabel("Gender")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df["Gender"].value_counts(normalize=True)
# Out:
# Male      0.916458
# Female    0.082972
# Other     0.000571
# Name: Gender, dtype: float64

# %% [markdown]
# Ooof the class looks very unbalanced when comparing Male to Female - Other might be dropped

# %%
# Let's check on clothing removal info
df["Removal of more than just outer clothing"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# Let's check on clothing removal info
df["Removal of more than just outer clothing"].value_counts(normalize=True)
# Out:
# False    0.954435
# True     0.045565
# Name: Removal of more than just outer clothing, dtype: float64

# %% [markdown]
# Again, a very high unbalance in both classes - even more if we convert the NaNs to False
#
# There are a lot of NaN values around this class...hmm what to do? (426549/660611) -> 64,6%

# %%
# and what gender does the NaNs most belong to?
df[df["Removal of more than just outer clothing"].isna()].Gender.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df[df["Removal of more than just outer clothing"].isna()].Gender.value_counts(normalize=True)
# Out:
# Male      0.925722
# Female    0.073863
# Other     0.000415
# Name: Gender, dtype: float64

# %% [markdown]
# It still presents the same distribution has the Gender in the dataset - need to ask about this to the client since this class that we need to track is very much filled with NaNs

# %%
# Let's check ethnicity now
df["Self-defined ethnicity"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["Officer-defined ethnicity"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# the latter seems a much better defined class but it might introduce the officer's bias

# %%
# Misc types of distribution
df["Type"].value_counts().plot(kind="bar") # might be a good class for one hot encoding?
# Out:
# <AxesSubplot:>

# %%
df["Part of a policing operation"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["Legislation"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["Object of search"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>
