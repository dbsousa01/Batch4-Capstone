# %% [markdown]
# notebook that evaluates the deployed model

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import (
    classification_report, 
    roc_auc_score, 
    confusion_matrix, 
    precision_score,
    roc_curve,
    recall_score
)
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Read the test set
df = pd.read_csv("data/test_1.csv", index_col="observation_id")

# convert the dictionaries to dataframes
list_json = [eval(row) for row in df.observation.values]
obs_df = pd.DataFrame(list_json)

# merge with the predicted and true outcome
outcomes_df = df[["predict", "true_class", "proba"]]

predictions_df = pd.merge(obs_df, outcomes_df, left_on="observation_id", right_on="observation_id")
predictions_df.set_index("observation_id", inplace=True)

# %%
predictions_df
# Out:
#                                                            Type  \
# observation_id
# cf46ed6e-e6bb-4bc9-959d-ef2e5a8162a0              Person search
# 3601e51b-f40a-4466-b884-d9284497462c              Person search
# 95dae6a9-6775-4862-815f-61cf1b586384              Person search
# 467c4766-3a3f-489d-bf09-5a698748499e              Person search
# c6d2de91-445e-40f7-9e5f-9d572f8bb232              Person search
# ...                                                         ...
# e8055287-1a71-4976-9b98-3b960c00421d  Person and Vehicle search
# 6b3dcd45-2403-4460-a8d8-b4f2e5ddc3ae              Person search
# b81e0607-3231-41ad-9807-86e754f0a4bd              Person search
# d4a4a31c-5a17-46d5-bec8-f0db2a289305              Person search
# 0cc3ae49-ebad-487b-9024-5c0943a3bca3              Person search
#
#                                                            Date  \
# observation_id
# cf46ed6e-e6bb-4bc9-959d-ef2e5a8162a0  2020-01-01T01:45:00+00:00
# 3601e51b-f40a-4466-b884-d9284497462c  2020-01-01T02:53:14+00:00
# 95dae6a9-6775-4862-815f-61cf1b586384  2020-01-01T04:43:00+00:00
# 467c4766-3a3f-489d-bf09-5a698748499e  2020-01-01T05:08:30+00:00
# c6d2de91-445e-40f7-9e5f-9d572f8bb232  2020-01-01T05:10:30+00:00
# ...                                                         ...
# e8055287-1a71-4976-9b98-3b960c00421d  2020-07-02T20:21:00+00:00
# 6b3dcd45-2403-4460-a8d8-b4f2e5ddc3ae  2020-07-03T09:19:37+00:00
# b81e0607-3231-41ad-9807-86e754f0a4bd  2020-07-03T12:13:00+00:00
# d4a4a31c-5a17-46d5-bec8-f0db2a289305  2020-07-04T00:00:00+00:00
# 0cc3ae49-ebad-487b-9024-5c0943a3bca3  2020-07-04T22:23:00+00:00
#
#                                      Part of a policing operation   Latitude  \
# observation_id
# cf46ed6e-e6bb-4bc9-959d-ef2e5a8162a0                        False        NaN
# 3601e51b-f40a-4466-b884-d9284497462c                         None        NaN
# 95dae6a9-6775-4862-815f-61cf1b586384                         True        NaN
# 467c4766-3a3f-489d-bf09-5a698748499e                         None  51.512598
# c6d2de91-445e-40f7-9e5f-9d572f8bb232                         None  51.512598
# ...                                                           ...        ...
# e8055287-1a71-4976-9b98-3b960c00421d                         True        NaN
# 6b3dcd45-2403-4460-a8d8-b4f2e5ddc3ae                         None  51.517244
# b81e0607-3231-41ad-9807-86e754f0a4bd                         True        NaN
# d4a4a31c-5a17-46d5-bec8-f0db2a289305                         None  54.762334
# 0cc3ae49-ebad-487b-9024-5c0943a3bca3                        False        NaN
#
#                                       Longitude  Gender Age range  \
# observation_id
# cf46ed6e-e6bb-4bc9-959d-ef2e5a8162a0        NaN    Male     18-24
# 3601e51b-f40a-4466-b884-d9284497462c        NaN    Male     18-24
# 95dae6a9-6775-4862-815f-61cf1b586384        NaN  Female     18-24
# 467c4766-3a3f-489d-bf09-5a698748499e  -0.084967    Male     10-17
# c6d2de91-445e-40f7-9e5f-9d572f8bb232  -0.084967    Male     10-17
# ...                                         ...     ...       ...
# e8055287-1a71-4976-9b98-3b960c00421d        NaN    Male     18-24
# 6b3dcd45-2403-4460-a8d8-b4f2e5ddc3ae  -0.080376    Male   over 34
# b81e0607-3231-41ad-9807-86e754f0a4bd        NaN    Male     25-34
# d4a4a31c-5a17-46d5-bec8-f0db2a289305  -1.316834    Male   over 34
# 0cc3ae49-ebad-487b-9024-5c0943a3bca3        NaN  Female     18-24
#
#                                      Officer-defined ethnicity  \
# observation_id
# cf46ed6e-e6bb-4bc9-959d-ef2e5a8162a0                     White
# 3601e51b-f40a-4466-b884-d9284497462c                     White
# 95dae6a9-6775-4862-815f-61cf1b586384                     Mixed
# 467c4766-3a3f-489d-bf09-5a698748499e                     Black
# c6d2de91-445e-40f7-9e5f-9d572f8bb232                     Black
# ...                                                        ...
# e8055287-1a71-4976-9b98-3b960c00421d                     Asian
# 6b3dcd45-2403-4460-a8d8-b4f2e5ddc3ae                     Asian
# b81e0607-3231-41ad-9807-86e754f0a4bd                     Mixed
# d4a4a31c-5a17-46d5-bec8-f0db2a289305                     White
# 0cc3ae49-ebad-487b-9024-5c0943a3bca3                     White
#
#                                                                             Legislation  \
# observation_id
# cf46ed6e-e6bb-4bc9-959d-ef2e5a8162a0  Police and Criminal Evidence Act 1984 (section 1)
# 3601e51b-f40a-4466-b884-d9284497462c  Police and Criminal Evidence Act 1984 (section 1)
# 95dae6a9-6775-4862-815f-61cf1b586384              Misuse of Drugs Act 1971 (section 23)
# 467c4766-3a3f-489d-bf09-5a698748499e              Misuse of Drugs Act 1971 (section 23)
# c6d2de91-445e-40f7-9e5f-9d572f8bb232              Misuse of Drugs Act 1971 (section 23)
# ...                                                                                 ...
# e8055287-1a71-4976-9b98-3b960c00421d              Misuse of Drugs Act 1971 (section 23)
# 6b3dcd45-2403-4460-a8d8-b4f2e5ddc3ae  Police and Criminal Evidence Act 1984 (section 1)
# b81e0607-3231-41ad-9807-86e754f0a4bd              Misuse of Drugs Act 1971 (section 23)
# d4a4a31c-5a17-46d5-bec8-f0db2a289305  Police and Criminal Evidence Act 1984 (section 1)
# 0cc3ae49-ebad-487b-9024-5c0943a3bca3              Misuse of Drugs Act 1971 (section 23)
#
#                                               Object of search  \
# observation_id
# cf46ed6e-e6bb-4bc9-959d-ef2e5a8162a0         Offensive weapons
# 3601e51b-f40a-4466-b884-d9284497462c              Stolen goods
# 95dae6a9-6775-4862-815f-61cf1b586384          Controlled drugs
# 467c4766-3a3f-489d-bf09-5a698748499e          Controlled drugs
# c6d2de91-445e-40f7-9e5f-9d572f8bb232          Controlled drugs
# ...                                                        ...
# e8055287-1a71-4976-9b98-3b960c00421d          Controlled drugs
# 6b3dcd45-2403-4460-a8d8-b4f2e5ddc3ae  Article for use in theft
# b81e0607-3231-41ad-9807-86e754f0a4bd          Controlled drugs
# d4a4a31c-5a17-46d5-bec8-f0db2a289305  Article for use in theft
# 0cc3ae49-ebad-487b-9024-5c0943a3bca3          Controlled drugs
#
#                                               station  predict  true_class  \
# observation_id
# cf46ed6e-e6bb-4bc9-959d-ef2e5a8162a0  nottinghamshire        0           0
# 3601e51b-f40a-4466-b884-d9284497462c   city-of-london        0           0
# 95dae6a9-6775-4862-815f-61cf1b586384  nottinghamshire        1           0
# 467c4766-3a3f-489d-bf09-5a698748499e   city-of-london        1           0
# c6d2de91-445e-40f7-9e5f-9d572f8bb232   city-of-london        1           0
# ...                                               ...      ...         ...
# e8055287-1a71-4976-9b98-3b960c00421d  nottinghamshire        1           0
# 6b3dcd45-2403-4460-a8d8-b4f2e5ddc3ae   city-of-london        0           1
# b81e0607-3231-41ad-9807-86e754f0a4bd  nottinghamshire        1           1
# d4a4a31c-5a17-46d5-bec8-f0db2a289305           durham        0           0
# 0cc3ae49-ebad-487b-9024-5c0943a3bca3  nottinghamshire        1           0
#
#                                          proba
# observation_id
# cf46ed6e-e6bb-4bc9-959d-ef2e5a8162a0  0.417262
# 3601e51b-f40a-4466-b884-d9284497462c  0.448492
# 95dae6a9-6775-4862-815f-61cf1b586384  0.537857
# 467c4766-3a3f-489d-bf09-5a698748499e  0.508692
# c6d2de91-445e-40f7-9e5f-9d572f8bb232  0.508692
# ...                                        ...
# e8055287-1a71-4976-9b98-3b960c00421d  0.569119
# 6b3dcd45-2403-4460-a8d8-b4f2e5ddc3ae  0.395154
# b81e0607-3231-41ad-9807-86e754f0a4bd  0.534407
# d4a4a31c-5a17-46d5-bec8-f0db2a289305  0.393986
# 0cc3ae49-ebad-487b-9024-5c0943a3bca3  0.540392
#
# [4000 rows x 14 columns]

# %%
predictions_df.isna().sum()
# Out:
# Type                               0
# Date                               0
# Part of a policing operation    1797
# Latitude                        2526
# Longitude                       2526
# Gender                             0
# Age range                          0
# Officer-defined ethnicity          0
# Legislation                        1
# Object of search                   0
# station                            0
# predict                            0
# true_class                         0
# dtype: int64

# %%
predictions_df.groupby("true_class").count()
# Out:
#             Type  Date  Part of a policing operation  Latitude  Longitude  \
# true_class
# 0           2887  2887                          1681       963        963
# 1           1113  1113                           522       511        511
#
#             Gender  Age range  Officer-defined ethnicity  Legislation  \
# true_class
# 0             2887       2887                       2887         2886
# 1             1113       1113                       1113         1113
#
#             Object of search  station  predict
# true_class
# 0                       2887     2887     2887
# 1                       1113     1113     1113

# %%
predictions_df.groupby("predict").count()
# Out:
#          Type  Date  Part of a policing operation  Latitude  Longitude  \
# predict
# 0        1322  1322                           504       722        722
# 1        2678  2678                          1699       752        752
#
#          Gender  Age range  Officer-defined ethnicity  Legislation  \
# predict
# 0          1322       1322                       1322         1321
# 1          2678       2678                       2678         2678
#
#          Object of search  station  true_class
# predict
# 0                    1322     1322        1322
# 1                    2678     2678        2678

# %% [markdown]
# how many observations we had per station?

# %%
predictions_df.groupby(["station", "true_class"]).count()
# Out:
#                             Type  Date  Part of a policing operation  \
# station         true_class
# cambridgeshire  0             26    26                             0
#                 1              5     5                             0
# city-of-london  0            964   964                             0
#                 1            308   308                             0
# durham          0            216   216                             0
#                 1            278   278                             0
# nottinghamshire 0           1681  1681                          1681
#                 1            522   522                           522
#
#                             Latitude  Longitude  Gender  Age range  \
# station         true_class
# cambridgeshire  0                 26         26      26         26
#                 1                  5          5       5          5
# city-of-london  0                721        721     964        964
#                 1                228        228     308        308
# durham          0                216        216     216        216
#                 1                278        278     278        278
# nottinghamshire 0                  0          0    1681       1681
#                 1                  0          0     522        522
#
#                             Officer-defined ethnicity  Legislation  \
# station         true_class
# cambridgeshire  0                                  26           26
#                 1                                   5            5
# city-of-london  0                                 964          964
#                 1                                 308          308
# durham          0                                 216          216
#                 1                                 278          278
# nottinghamshire 0                                1681         1680
#                 1                                 522          522
#
#                             Object of search  predict
# station         true_class
# cambridgeshire  0                         26       26
#                 1                          5        5
# city-of-london  0                        964      964
#                 1                        308      308
# durham          0                        216      216
#                 1                        278      278
# nottinghamshire 0                       1681     1681
#                 1                        522      522

# %%
predictions_df.groupby(["station", "predict"]).count()
# Out:
#                          Type  Date  Part of a policing operation  Latitude  \
# station         predict
# cambridgeshire  0           8     8                             0         8
#                 1          23    23                             0        23
# city-of-london  0         566   566                             0       470
#                 1         706   706                             0       479
# durham          0         244   244                             0       244
#                 1         250   250                             0       250
# nottinghamshire 0         504   504                           504         0
#                 1        1699  1699                          1699         0
#
#                          Longitude  Gender  Age range  \
# station         predict
# cambridgeshire  0                8       8          8
#                 1               23      23         23
# city-of-london  0              470     566        566
#                 1              479     706        706
# durham          0              244     244        244
#                 1              250     250        250
# nottinghamshire 0                0     504        504
#                 1                0    1699       1699
#
#                          Officer-defined ethnicity  Legislation  \
# station         predict
# cambridgeshire  0                                8            8
#                 1                               23           23
# city-of-london  0                              566          566
#                 1                              706          706
# durham          0                              244          244
#                 1                              250          250
# nottinghamshire 0                              504          503
#                 1                             1699         1699
#
#                          Object of search  true_class
# station         predict
# cambridgeshire  0                       8           8
#                 1                      23          23
# city-of-london  0                     566         566
#                 1                     706         706
# durham          0                     244         244
#                 1                     250         250
# nottinghamshire 0                     504         504
#                 1                    1699        1699

# %%
predictions_df.groupby(["Object of search", "true_class"]).count()
# Out:
#                                                 Type  Date  \
# Object of search                    true_class
# Article for use in theft            0            404   404
#                                     1             86    86
# Articles for use in criminal damage 0             22    22
#                                     1              6     6
# Controlled drugs                    0           1856  1856
#                                     1            825   825
# Evidence of offences under the Act  0             27    27
#                                     1              2     2
# Firearms                            0             14    14
#                                     1              2     2
# Fireworks                           1              1     1
# Game or poaching equipment          0              6     6
#                                     1              2     2
# Offensive weapons                   0            323   323
#                                     1             61    61
# Stolen goods                        0            235   235
#                                     1            128   128
#
#                                                 Part of a policing operation  \
# Object of search                    true_class
# Article for use in theft            0                                    140
#                                     1                                      7
# Articles for use in criminal damage 0                                     10
#                                     1                                      0
# Controlled drugs                    0                                   1239
#                                     1                                    468
# Evidence of offences under the Act  0                                      0
#                                     1                                      0
# Firearms                            0                                      5
#                                     1                                      0
# Fireworks                           1                                      0
# Game or poaching equipment          0                                      0
#                                     1                                      0
# Offensive weapons                   0                                    221
#                                     1                                     25
# Stolen goods                        0                                     66
#                                     1                                     22
#
#                                                 Latitude  Longitude  Gender  \
# Object of search                    true_class
# Article for use in theft            0                231        231     404
#                                     1                 70         70      86
# Articles for use in criminal damage 0                 12         12      22
#                                     1                  6          6       6
# Controlled drugs                    0                454        454    1856
#                                     1                295        295     825
# Evidence of offences under the Act  0                 20         20      27
#                                     1                  2          2       2
# Firearms                            0                  5          5      14
#                                     1                  2          2       2
# Fireworks                           1                  1          1       1
# Game or poaching equipment          0                  6          6       6
#                                     1                  2          2       2
# Offensive weapons                   0                 73         73     323
#                                     1                 32         32      61
# Stolen goods                        0                162        162     235
#                                     1                101        101     128
#
#                                                 Age range  \
# Object of search                    true_class
# Article for use in theft            0                 404
#                                     1                  86
# Articles for use in criminal damage 0                  22
#                                     1                   6
# Controlled drugs                    0                1856
#                                     1                 825
# Evidence of offences under the Act  0                  27
#                                     1                   2
# Firearms                            0                  14
#                                     1                   2
# Fireworks                           1                   1
# Game or poaching equipment          0                   6
#                                     1                   2
# Offensive weapons                   0                 323
#                                     1                  61
# Stolen goods                        0                 235
#                                     1                 128
#
#                                                 Officer-defined ethnicity  \
# Object of search                    true_class
# Article for use in theft            0                                 404
#                                     1                                  86
# Articles for use in criminal damage 0                                  22
#                                     1                                   6
# Controlled drugs                    0                                1856
#                                     1                                 825
# Evidence of offences under the Act  0                                  27
#                                     1                                   2
# Firearms                            0                                  14
#                                     1                                   2
# Fireworks                           1                                   1
# Game or poaching equipment          0                                   6
#                                     1                                   2
# Offensive weapons                   0                                 323
#                                     1                                  61
# Stolen goods                        0                                 235
#                                     1                                 128
#
#                                                 Legislation  station  predict
# Object of search                    true_class
# Article for use in theft            0                   404      404      404
#                                     1                    86       86       86
# Articles for use in criminal damage 0                    22       22       22
#                                     1                     6        6        6
# Controlled drugs                    0                  1856     1856     1856
#                                     1                   825      825      825
# Evidence of offences under the Act  0                    27       27       27
#                                     1                     2        2        2
# Firearms                            0                    14       14       14
#                                     1                     2        2        2
# Fireworks                           1                     1        1        1
# Game or poaching equipment          0                     6        6        6
#                                     1                     2        2        2
# Offensive weapons                   0                   322      323      323
#                                     1                    61       61       61
# Stolen goods                        0                   235      235      235
#                                     1                   128      128      128

# %%
predictions_df.groupby(["Object of search", "predict"]).count()
# Out:
#                                              Type  Date  \
# Object of search                    predict
# Article for use in theft            0         490   490
# Articles for use in criminal damage 0          28    28
# Controlled drugs                    0          12    12
#                                     1        2669  2669
# Evidence of offences under the Act  0          20    20
#                                     1           9     9
# Firearms                            0          16    16
# Fireworks                           0           1     1
# Game or poaching equipment          0           8     8
# Offensive weapons                   0         384   384
# Stolen goods                        0         363   363
#
#                                              Part of a policing operation  \
# Object of search                    predict
# Article for use in theft            0                                 147
# Articles for use in criminal damage 0                                  10
# Controlled drugs                    0                                   8
#                                     1                                1699
# Evidence of offences under the Act  0                                   0
#                                     1                                   0
# Firearms                            0                                   5
# Fireworks                           0                                   0
# Game or poaching equipment          0                                   0
# Offensive weapons                   0                                 246
# Stolen goods                        0                                  88
#
#                                              Latitude  Longitude  Gender  \
# Object of search                    predict
# Article for use in theft            0             301        301     490
# Articles for use in criminal damage 0              18         18      28
# Controlled drugs                    0               4          4      12
#                                     1             745        745    2669
# Evidence of offences under the Act  0              15         15      20
#                                     1               7          7       9
# Firearms                            0               7          7      16
# Fireworks                           0               1          1       1
# Game or poaching equipment          0               8          8       8
# Offensive weapons                   0             105        105     384
# Stolen goods                        0             263        263     363
#
#                                              Age range  \
# Object of search                    predict
# Article for use in theft            0              490
# Articles for use in criminal damage 0               28
# Controlled drugs                    0               12
#                                     1             2669
# Evidence of offences under the Act  0               20
#                                     1                9
# Firearms                            0               16
# Fireworks                           0                1
# Game or poaching equipment          0                8
# Offensive weapons                   0              384
# Stolen goods                        0              363
#
#                                              Officer-defined ethnicity  \
# Object of search                    predict
# Article for use in theft            0                              490
# Articles for use in criminal damage 0                               28
# Controlled drugs                    0                               12
#                                     1                             2669
# Evidence of offences under the Act  0                               20
#                                     1                                9
# Firearms                            0                               16
# Fireworks                           0                                1
# Game or poaching equipment          0                                8
# Offensive weapons                   0                              384
# Stolen goods                        0                              363
#
#                                              Legislation  station  true_class  \
# Object of search                    predict
# Article for use in theft            0                490      490         490
# Articles for use in criminal damage 0                 28       28          28
# Controlled drugs                    0                 12       12          12
#                                     1               2669     2669        2669
# Evidence of offences under the Act  0                 20       20          20
#                                     1                  9        9           9
# Firearms                            0                 16       16          16
# Fireworks                           0                  1        1           1
# Game or poaching equipment          0                  8        8           8
# Offensive weapons                   0                383      384         384
# Stolen goods                        0                363      363         363
#
#                                              proba
# Object of search                    predict
# Article for use in theft            0          490
# Articles for use in criminal damage 0           28
# Controlled drugs                    0           12
#                                     1         2669
# Evidence of offences under the Act  0           20
#                                     1            9
# Firearms                            0           16
# Fireworks                           0            1
# Game or poaching equipment          0            8
# Offensive weapons                   0          384
# Stolen goods                        0          363

# %% [markdown]
# ### Distribution of classes

# %%
predictions_df["Age range"].value_counts(normalize=True)
# Out:
# 18-24       0.35425
# 25-34       0.29025
# over 34     0.24600
# 10-17       0.10750
# under 10    0.00200
# Name: Age range, dtype: float64

# %%
predictions_df["Gender"].value_counts(normalize=True)
# Out:
# Male      0.91425
# Female    0.08225
# Other     0.00350
# Name: Gender, dtype: float64

# %%
predictions_df["Officer-defined ethnicity"].value_counts(normalize=True)
# Out:
# White    0.63225
# Black    0.16350
# Asian    0.13650
# Mixed    0.04400
# Other    0.02375
# Name: Officer-defined ethnicity, dtype: float64

# %%
predictions_df["Type"].value_counts(normalize=True)
# Out:
# Person search                0.74375
# Person and Vehicle search    0.25625
# Name: Type, dtype: float64

# %%
predictions_df["Part of a policing operation"].value_counts(normalize=True)
# Out:
# False    0.548797
# True     0.451203
# Name: Part of a policing operation, dtype: float64

# %% [markdown]
# ## Performance of the model with the test we know the outcome

# %%
y_pred = predictions_df["predict"].values
y_test = predictions_df["true_class"].values

# %%
roc_auc_score(y_test, y_pred)
# Out:
# 0.5478312950422799

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1031, 1856],
#        [ 291,  822]])

# %%
classification_report(y_test, y_pred, target_names=["Not Successful Search", "Successful Search"])
# Out:
# '                       precision    recall  f1-score   support\n\nNot Successful Search       0.78      0.36      0.49      2887\n    Successful Search       0.31      0.74      0.43      1113\n\n             accuracy                           0.46      4000\n            macro avg       0.54      0.55      0.46      4000\n         weighted avg       0.65      0.46      0.47      4000\n'

# %% [markdown]
# Plot the ROC Curve

# %%
ns_probs = [0 for _ in range(len(y_test))]
model_probs = predictions_df.proba.values

ns_auc = roc_auc_score(y_test, ns_probs)
model_auc = roc_auc_score(y_test, model_probs)

print('No Skill: ROC AUC=%.3f' % (ns_auc))
print('Model: ROC AUC=%.3f' % (model_auc))
# Out:
# No Skill: ROC AUC=0.500
# Model: ROC AUC=0.572

# %%
# calculate roc curves
ns_fpr, ns_tpr, _ = roc_curve(y_test, ns_probs)
mdl_fpr, mdl_tpr, _ = roc_curve(y_test, model_probs)

# %%
# plot the roc curve for the model
plt.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
plt.plot(mdl_fpr, mdl_tpr, marker='.', label='Model')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plot
plt.show()

# %% [markdown]
# ### Precision between stations

# %%
def comparison_between_stations(
    X_test: pd.DataFrame, y_true: np.asarray, y_pred: np.asarray, min_samples: int = 30
):
    """
        Function that returns the precision score for each station

    :param X_test: DataFrame with the test set that we want to use for comparison
    :param y_true: np.array with the true y labels
    :param y_pred: np.array with the predicted y labels
    :param min_samples: minimum samples for the entry to be considered
    :return: sorted dict with the stations and their precisions
    """
    stations = X_test["station"].unique()
    precisions = {}

    # For every station
    for station in stations:

        # Create a mask that filters according to station
        mask = X_test["station"] == station

        # if the dataframe filtered with the mask has more than 30 rows
        if np.sum(mask) > min_samples:
            # generate the dict key with the two classes
            precisions[station] = precision_score(
                y_true[mask], y_pred[mask], pos_label=1
            )
    return dict(sorted(precisions.items(), key=lambda item: item[1]))

# %%
precision_per_station = comparison_between_stations(predictions_df, y_test, y_pred)
precision_per_station
# Out:
# {'cambridgeshire': 0.21739130434782608,
#  'city-of-london': 0.26912181303116145,
#  'nottinghamshire': 0.27486756915832844,
#  'durham': 0.64}

# %% [markdown]
# ### Check discrimination in subgroups (station, ethnicity and gender)

# %%
def verify_no_discrimination(
    X_test,
    y_true,
    y_pred,
    sensitive_columns_tuple = ("Officer-defined ethnicity", "Gender"),
    max_diff = 0.05,
    min_samples = 30,
):
    """
            Verifies that no station has discrimination in between protected column tuples (ethnicity, gender)

    :param X_test: DataFrame with the testing data
    :param y_true: np.array with the true labels
    :param y_pred: np.array with the predicted labels
    :param sensitive_columns_tuple: tuple with the sensitive_columns
    :param max_diff: max difference between columns, if greater then there is discrimination
    :param min_samples: minimum nb of samples to be considered
    :return:
    """

    first_sensitive_column, second_sensitive_column = sensitive_columns_tuple

    stations = X_test["station"].unique()
    sensitive_classes = X_test[first_sensitive_column].unique()
    second_sensitive_classes = X_test[second_sensitive_column].unique()

    is_satisfied = True
    problematic_stations = []
    good_stations = []
    ignored_stations = []
    all_precisions = []
    # For every station
    for station in stations:
        precisions = {}
        # For every classes
        for sensitive_class in sensitive_classes:
            for second_sensitive_class in second_sensitive_classes:

                # Create a mask that filters according to class values
                mask = (
                    (X_test[first_sensitive_column] == sensitive_class)
                    & (X_test["station"] == station)
                    & (X_test[second_sensitive_column] == second_sensitive_class)
                )

                # if the dataframe filtered with the mask has more than 30 rows
                if np.sum(mask) > min_samples:

                    # generate the dict key with the two classes
                    key = "{0} - {1}".format(sensitive_class, second_sensitive_class)
                    precisions[key] = precision_score(
                        y_true[mask], y_pred[mask], pos_label=1
                    )

        if len(precisions) > 1:
            diff = np.max(list(precisions.values())) - np.min(list(precisions.values()))

            if diff > max_diff:
                is_satisfied = False
                print(station, diff, precisions)
                problematic_stations.append((station, diff, precisions))
                all_precisions.append(precisions)
            else:
                good_stations.append((station, diff, precisions))
        else:
            ignored_stations.append((station, None, []))

    global_precisions = {}
    for station in stations:
        for sensitive_class in sensitive_classes:
            for second_sensitive_class in second_sensitive_classes:
                mask = (
                    (X_test[first_sensitive_column] == sensitive_class)
                    & (X_test[second_sensitive_column] == second_sensitive_class)
                    & (X_test["station"] == station)
                )

                if np.sum(mask) > min_samples:
                    # key to filter the dictionary
                    key = "{0} - {1}".format(sensitive_class, second_sensitive_class)
                    global_precisions[key] = precision_score(
                        y_true[mask], y_pred[mask], pos_label=1
                    )

    if len(precisions) > 1:
        diff = np.max(list(precisions.values())) - np.min(list(precisions.values()))
        if diff > max_diff:
            is_satisfied = False

    return is_satisfied, problematic_stations, good_stations, global_precisions, all_precisions

# %%
(
    is_satisfied,
    problematic_stations,
    good_stations,
    global_precisions,
    all_precisions
) = verify_no_discrimination(predictions_df, y_test, y_pred)
# Out:
# nottinghamshire 0.07299270072992703 {'White - Male': 0.29927007299270075, 'White - Female': 0.25, 'Mixed - Male': 0.22627737226277372, 'Black - Male': 0.26639344262295084, 'Asian - Male': 0.23728813559322035}
# city-of-london 0.07250000000000001 {'White - Male': 0.3125, 'White - Female': 0.2857142857142857, 'Black - Male': 0.26732673267326734, 'Asian - Male': 0.24, 'Other - Male': 0.2413793103448276}
# durham 0.11544804837822975 {'White - Male': 0.6448598130841121, 'White - Female': 0.5294117647058824}

# %%
if not is_satisfied:
    print("Requirement failed 😢")
    print("Global rates: {}".format(global_precisions))
    print("Num problematic departments: {}".format(len(problematic_stations)))
    print("Num good departments: {}".format(len(good_stations)))
# Out:
# Requirement failed 😢
# Global rates: {'White - Male': 0.6448598130841121, 'White - Female': 0.5294117647058824, 'Mixed - Male': 0.22627737226277372, 'Black - Male': 0.26732673267326734, 'Asian - Male': 0.24, 'Other - Male': 0.2413793103448276}
# Num problematic departments: 3
# Num good departments: 0

# %%
problematic_stations
# Out:
# [('nottinghamshire',
#   0.07299270072992703,
#   {'White - Male': 0.29927007299270075,
#    'White - Female': 0.25,
#    'Mixed - Male': 0.22627737226277372,
#    'Black - Male': 0.26639344262295084,
#    'Asian - Male': 0.23728813559322035}),
#  ('city-of-london',
#   0.07250000000000001,
#   {'White - Male': 0.3125,
#    'White - Female': 0.2857142857142857,
#    'Black - Male': 0.26732673267326734,
#    'Asian - Male': 0.24,
#    'Other - Male': 0.2413793103448276}),
#  ('durham',
#   0.11544804837822975,
#   {'White - Male': 0.6448598130841121, 'White - Female': 0.5294117647058824})]

# %%
good_stations
# Out:
# []

# %%
all_precisions
# Out:
# [{'White - Male': 0.29927007299270075,
#   'White - Female': 0.25,
#   'Mixed - Male': 0.22627737226277372,
#   'Black - Male': 0.26639344262295084,
#   'Asian - Male': 0.23728813559322035},
#  {'White - Male': 0.3125,
#   'White - Female': 0.2857142857142857,
#   'Black - Male': 0.26732673267326734,
#   'Asian - Male': 0.24,
#   'Other - Male': 0.2413793103448276},
#  {'White - Male': 0.6448598130841121, 'White - Female': 0.5294117647058824}]

# %%
plt.rcParams['figure.figsize'] = [20, 12]
plt.rcParams['figure.dpi'] = 200 # 200 e.g. is really fine, but slower
fig, ax = plt.subplots()

stations = []
for details in problematic_stations:
    stations.append(details[0])
    avg_dif = details[1]
    diffs = details[2]
    keys = ["{}-{}".format(details[0][0],key) for key in diffs.keys()]
    plt.bar(keys, diffs.values(), align="center", width=0.3)
    
plt.legend(stations)
plt.ylabel("Diffs value")
plt.xlabel("Ethnicities - Gender")
plt.show()

# %%
def verify_discovery_rate(
    X_test,
    y_true,
    y_pred,
    sensitive_columns_tuple = ("Officer-defined ethnicity", "Object of search"),
    max_diff = 0.05,
    min_samples = 30,
):
    """
            Verifies that no station has discrimination in between protected column tuples (ethnicity, gender)

    :param X_test: DataFrame with the testing data
    :param y_true: np.array with the true labels
    :param y_pred: np.array with the predicted labels
    :param sensitive_columns_tuple: tuple with the sensitive_columns
    :param max_diff: max difference between columns, if greater then there is discrimination
    :param min_samples: minimum nb of samples to be considered
    :return:
    """

    first_sensitive_column, second_sensitive_column = sensitive_columns_tuple

    stations = X_test["station"].unique()
    sensitive_classes = X_test[first_sensitive_column].unique()
    second_sensitive_classes = X_test[second_sensitive_column].unique()

    is_satisfied = True
    problematic_stations = []
    good_stations = []
    ignored_stations = []
    all_precisions = []
    # For every station
    for station in stations:
        precisions = {}
        # For every classes
        for sensitive_class in sensitive_classes:
            for second_sensitive_class in second_sensitive_classes:

                # Create a mask that filters according to class values
                mask = (
                    (X_test[first_sensitive_column] == sensitive_class)
                    & (X_test["station"] == station)
                    & (X_test[second_sensitive_column] == second_sensitive_class)
                )

                # if the dataframe filtered with the mask has more than 30 rows
                if np.sum(mask) > min_samples:

                    # generate the dict key with the two classes
                    key = "{0} - {1}".format(sensitive_class, second_sensitive_class)
                    precisions[key] = recall_score(
                        y_true[mask], y_pred[mask], pos_label=1
                    )

        if len(precisions) > 1:
            diff = np.max(list(precisions.values())) - np.min(list(precisions.values()))

            if diff > max_diff:
                is_satisfied = False
                print(station, diff, precisions)
                problematic_stations.append((station, diff, precisions))
                all_precisions.append(precisions)
            else:
                good_stations.append((station, diff, precisions))
        else:
            ignored_stations.append((station, None, []))

    global_precisions = {}
    for station in stations:
        for sensitive_class in sensitive_classes:
            for second_sensitive_class in second_sensitive_classes:
                mask = (
                    (X_test[first_sensitive_column] == sensitive_class)
                    & (X_test[second_sensitive_column] == second_sensitive_class)
                    & (X_test["station"] == station)
                )

                if np.sum(mask) > min_samples:
                    # key to filter the dictionary
                    key = "{0} - {1}".format(sensitive_class, second_sensitive_class)
                    global_precisions[key] = precision_score(
                        y_true[mask], y_pred[mask], pos_label=1
                    )

    if len(precisions) > 1:
        diff = np.max(list(precisions.values())) - np.min(list(precisions.values()))
        if diff > max_diff:
            is_satisfied = False

    return is_satisfied, problematic_stations, good_stations, global_precisions, all_precisions

# %%
(
    is_satisfied,
    problematic_stations,
    good_stations,
    global_precisions,
    all_precisions
) = verify_discovery_rate(predictions_df, y_test, y_pred)
# Out:
# nottinghamshire 1.0 {'White - Offensive weapons': 0.0, 'White - Stolen goods': 0.0, 'White - Controlled drugs': 1.0, 'White - Article for use in theft': 0.0, 'Mixed - Controlled drugs': 0.9705882352941176, 'Black - Offensive weapons': 0.0, 'Black - Controlled drugs': 1.0, 'Asian - Controlled drugs': 1.0}
# city-of-london 1.0 {'White - Offensive weapons': 0.0, 'White - Stolen goods': 0.0, 'White - Controlled drugs': 1.0, 'White - Article for use in theft': 0.0, 'Black - Offensive weapons': 0.0, 'Black - Controlled drugs': 1.0, 'Black - Article for use in theft': 0.0, 'Asian - Controlled drugs': 1.0, 'Other - Controlled drugs': 1.0}
# durham 0.9872611464968153 {'White - Offensive weapons': 0.0, 'White - Stolen goods': 0.0, 'White - Controlled drugs': 0.9872611464968153, 'White - Article for use in theft': 0.0}
# /Users/dbr7755/Documents/ldssa/Batch4-Capstone/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dbr7755/Documents/ldssa/Batch4-Capstone/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dbr7755/Documents/ldssa/Batch4-Capstone/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dbr7755/Documents/ldssa/Batch4-Capstone/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dbr7755/Documents/ldssa/Batch4-Capstone/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dbr7755/Documents/ldssa/Batch4-Capstone/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dbr7755/Documents/ldssa/Batch4-Capstone/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dbr7755/Documents/ldssa/Batch4-Capstone/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dbr7755/Documents/ldssa/Batch4-Capstone/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dbr7755/Documents/ldssa/Batch4-Capstone/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dbr7755/Documents/ldssa/Batch4-Capstone/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/dbr7755/Documents/ldssa/Batch4-Capstone/capstone/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
if not is_satisfied:
    print("Requirement failed 😢")
    print("Global rates: {}".format(global_precisions))
    print("Num problematic departments: {}".format(len(problematic_stations)))
    print("Num good departments: {}".format(len(good_stations)))
# Out:
# Requirement failed 😢
# Global rates: {'White - Offensive weapons': 0.0, 'White - Stolen goods': 0.0, 'White - Controlled drugs': 0.6431535269709544, 'White - Article for use in theft': 0.0, 'Mixed - Controlled drugs': 0.22448979591836735, 'Black - Offensive weapons': 0.0, 'Black - Controlled drugs': 0.2631578947368421, 'Asian - Controlled drugs': 0.22826086956521738, 'Black - Article for use in theft': 0.0, 'Other - Controlled drugs': 0.25806451612903225}
# Num problematic departments: 3
# Num good departments: 0

# %%
problematic_stations
# Out:
# [('nottinghamshire',
#   1.0,
#   {'White - Offensive weapons': 0.0,
#    'White - Stolen goods': 0.0,
#    'White - Controlled drugs': 1.0,
#    'White - Article for use in theft': 0.0,
#    'Mixed - Controlled drugs': 0.9705882352941176,
#    'Black - Offensive weapons': 0.0,
#    'Black - Controlled drugs': 1.0,
#    'Asian - Controlled drugs': 1.0}),
#  ('city-of-london',
#   1.0,
#   {'White - Offensive weapons': 0.0,
#    'White - Stolen goods': 0.0,
#    'White - Controlled drugs': 1.0,
#    'White - Article for use in theft': 0.0,
#    'Black - Offensive weapons': 0.0,
#    'Black - Controlled drugs': 1.0,
#    'Black - Article for use in theft': 0.0,
#    'Asian - Controlled drugs': 1.0,
#    'Other - Controlled drugs': 1.0}),
#  ('durham',
#   0.9872611464968153,
#   {'White - Offensive weapons': 0.0,
#    'White - Stolen goods': 0.0,
#    'White - Controlled drugs': 0.9872611464968153,
#    'White - Article for use in theft': 0.0})]

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 200 # 200 e.g. is really fine, but slower
fig, ax = plt.subplots()

stations = []
for details in problematic_stations:
    stations.append(details[0])
    avg_dif = details[1]
    diffs = details[2]
    keys = ["{}-{}".format(details[0][0],key) for key in diffs.keys()]
    plt.bar(keys, diffs.values(), align="center", width=0.3)
    
plt.legend(stations)
plt.ylabel("Recall score")
plt.xlabel("Ethnicities - Object of search")
plt.tight_layout()
plt.xticks(rotation=90)
plt.show()
